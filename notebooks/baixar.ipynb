# %%
import requests
import pandas as pd

# %%
resp = requests.get("https://dadosabertos.camara.leg.br/api/v2/deputados")
data = resp.json()

# %%
#dados vem apenas em jjon inicialmente
data
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'dados': [
#         {
#             'id': 204379,
#             'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379',
#             'nome': 'Acácio Favacho',
#             'siglaPartido': 'MDB',
#             'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
#             'siglaUf': 'AP',
#             'idLegislatura': 57,
#             'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204379.jpg',
#             'email': 'dep.acaciofavacho@camara.leg.br'
#         },
#         {
#             'id': 220714,
#             'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/220714',
#             'nome': 'Adail Filho',
#             'siglaPartido': 'REPUBLICANOS',
#             'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37908',
# ...

# %%
df_data = pd.DataFrame(data["dados"])

# %%
df_data['email'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# email
# dep.zucco@camara.leg.br               1
# dep.waldemaroliveira@camara.leg.br    1
# dep.vitorlippi@camara.leg.br          1
# dep.viniciusgurgel@camara.leg.br      1
# dep.viniciuscarvalho@camara.leg.br    1
#                                      ..
# dep.adrianodobaldy@camara.leg.br      1
# dep.adrianaventura@camara.leg.br      1
# dep.adolfoviana@camara.leg.br         1
# dep.adilsonbarroso@camara.leg.br      1
# dep.adailfilho@camara.leg.br          1
# Name: count, Length: 513, dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             513 non-null    int64
#  1   uri            513 non-null    object
#  2   nome           513 non-null    object
#  3   siglaPartido   513 non-null    object
#  4   uriPartido     513 non-null    object
#  5   siglaUf        513 non-null    object
#  6   idLegislatura  513 non-null    int64
#  7   urlFoto        513 non-null    object
#  8   email          513 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 36.2+ KB

# %%
df_data.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        id                                                uri             nome  \
# 0  204379  https://dadosabertos.camara.leg.br/api/v2/depu...   Acácio Favacho
# 1  220714  https://dadosabertos.camara.leg.br/api/v2/depu...      Adail Filho
# 2  221328  https://dadosabertos.camara.leg.br/api/v2/depu...  Adilson Barroso
# 3  204560  https://dadosabertos.camara.leg.br/api/v2/depu...     Adolfo Viana
# 4  204528  https://dadosabertos.camara.leg.br/api/v2/depu...  Adriana Ventura
#
#    siglaPartido                                         uriPartido siglaUf  \
# 0           MDB  https://dadosabertos.camara.leg.br/api/v2/part...      AP
# 1  REPUBLICANOS  https://dadosabertos.camara.leg.br/api/v2/part...      AM
# 2            PL  https://dadosabertos.camara.leg.br/api/v2/part...      SP
# ...
